# %% [markdown]
# <a href="https://colab.research.google.com/github/feliphearaujo/poland-used-cars-offers-machine-learning/blob/main/poland_used_cars_offers_with_pycaret.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Instale o category_encoders
# !pip install category_encoders
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.9/81.9 kB 4.8 MB/s eta 0:00:00
# ...

# %%
# !pip install pycaret --user
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 484.4/484.4 kB 6.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.4/153.4 kB 7.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 kB 20.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 8.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 11.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.4/46.4 kB 4.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.0/17.0 MB 41.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 4.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 60.0 MB/s eta 0:00:00
# ...

# %%
# !pip install mlflow
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.1/18.1 MB 73.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.5/83.5 kB 9.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.5/188.5 kB 20.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 19.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.1/148.1 kB 14.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 8.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 kB 8.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 6.6 MB/s eta 0:00:00
# ...
#   Created wheel for databricks-cli: filename=databricks_cli-0.17.7-py3-none-any.whl size=143860 sha256=40afb453405af8b78e7c57df4f48758836b8d3f94a37503872cb36c859317aba
#   Stored in directory: /root/.cache/pip/wheels/ae/63/93/5402c1a09c1868a59d0b05013484e07af97a9d7b3dbd5bd39a
# ...

# %%
from pycaret.regression import *

# %%
from sklearn.pipeline import Pipeline
from category_encoders import OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer

# %%
url="https://github.com/feliphearaujo/poland-used-cars-offers-machine-learning/blob/main/dataset/data.csv?raw=true"
df = pd.read_csv(url, sep = ",")

# %%
valor_especifico = 'km'
df = df[~df['year'].str.contains(valor_especifico)]

# Exibindo o DataFrame após a eliminação das linhas
print("\nDataFrame após a eliminação das linhas:")
print(df)

# %%
valor_especifico = 'cm'
df = df[~df['year'].str.contains(valor_especifico)]

# Exibindo o DataFrame após a eliminação das linhas
print("\nDataFrame após a eliminação das linhas:")
print(df)

# %%
valor_especifico = 'Elektryczny'
df = df[~df['year'].str.contains(valor_especifico)]

# Exibindo o DataFrame após a eliminação das linhas
print("\nDataFrame após a eliminação das linhas:")
print(df)

# %%
valor_especifico = 'Benzyna'
df = df[~df['year'].str.contains(valor_especifico)]

# Exibindo o DataFrame após a eliminação das linhas
print("\nDataFrame após a eliminação das linhas:")
print(df)

# %%
valor_especifico = 'Diesel'
df = df[~df['year'].str.contains(valor_especifico)]

# Exibindo o DataFrame após a eliminação das linhas
print("\nDataFrame após a eliminação das linhas:")
print(df)

# %%
valor_especifico = 'Hybryda'
df = df[~df['year'].str.contains(valor_especifico)]

# Exibindo o DataFrame após a eliminação das linhas
print("\nDataFrame após a eliminação das linhas:")
print(df)

# %%
opcoes_unicas = df['year'].unique()
print(opcoes_unicas)

contagem_opcoes = df['year'].value_counts()
print(contagem_opcoes)

# %%
df['year'] = df['year'].astype(float)

# %%
opcoes_unicas = df['engine_capacity'].unique()
print(opcoes_unicas)

contagem_opcoes = df['engine_capacity'].value_counts()
print(contagem_opcoes)

# %%
valor_especifico = 'cm3'
df = df[df['engine_capacity'].str.contains(valor_especifico)]

# %%
df['engine_capacity'] = df['engine_capacity'].str.replace(' cm3', '')

# Exibindo o DataFrame com "cm3" removido
print("\nDataFrame com 'cm3' removido:")
print(df)

# %%
df['engine_capacity'] = df['engine_capacity'].str.replace(' ', '')

# Exibindo o DataFrame com " " removido
print("\nDataFrame com ' ' removido:")
print(df)

# %%
df['engine_capacity'] = df['engine_capacity'].astype(float)

# %%
df["gearbox"] = df["gearbox"].astype('category')
df['gearbox'] = df['gearbox'].cat.codes

# %%
opcoes_unicas = df['brand'].unique()
print(opcoes_unicas)

contagem_opcoes = df['brand'].value_counts()
print(contagem_opcoes)

# %%
df["brand"] = df["brand"].astype('category')
df['brand'] = df['brand'].cat.codes

# %%
opcoes_unicas = df['model'].unique()
print(opcoes_unicas)

contagem_opcoes = df['model'].value_counts()
print(contagem_opcoes)

# %%
df["model"] = df["model"].astype('category')
df['model'] = df['model'].cat.codes

# %%
opcoes_unicas = df['mileage'].unique()
print(opcoes_unicas)

contagem_opcoes = df['mileage'].value_counts()
print(contagem_opcoes)

# %%
valor_especifico = 'km'
df = df[df['mileage'].str.contains(valor_especifico)]

# %%
df['mileage'] = df['mileage'].str.replace(' km', '')

# Exibindo o DataFrame com "cm3" removido
print("\nDataFrame com 'cm3' removido:")
print(df)

# %%
df['mileage'] = df['mileage'].str.replace(' ', '')

# Exibindo o DataFrame com " " removido
print("\nDataFrame com ' ' removido:")
print(df)

# %%
df['mileage'] = df['mileage'].astype(float)

# %%
opcoes_unicas = df['fuel_type'].unique()
print(opcoes_unicas)

contagem_opcoes = df['fuel_type'].value_counts()
print(contagem_opcoes)

# %%
coluna_fuel_type = df['fuel_type']

# Aplicando o get_dummies na coluna 'frutas'
dummies_fuel_type = pd.get_dummies(coluna_fuel_type, prefix='fuel_type')

# Concatenando as colunas binárias ao DataFrame original
df = pd.concat([df, dummies_fuel_type], axis=1)

# Exibindo o resultado
print(df)

# %%
df = df.drop('fuel_type', axis=1)

# %%
opcoes_unicas = df['city'].unique()
print(opcoes_unicas)

contagem_opcoes = df['city'].value_counts()
print(contagem_opcoes)

# %%
df["city"] = df["city"].astype('category')
df['city'] = df['city'].cat.codes

# %%
opcoes_unicas = df['voivodeship'].unique()
print(opcoes_unicas)

contagem_opcoes = df['voivodeship'].value_counts()
print(contagem_opcoes)

# %%
coluna_fuel_type = df['voivodeship']

# Aplicando o get_dummies na coluna 'frutas'
dummies_fuel_type = pd.get_dummies(coluna_fuel_type, prefix='voivodeship')

# Concatenando as colunas binárias ao DataFrame original
df = pd.concat([df, dummies_fuel_type], axis=1)

# Exibindo o resultado
print(df)

# %%
df = df.drop('voivodeship', axis=1)

# %%
s = setup(df
          ,target = 'price_in_pln'
          #,transform_target = True
          #,remove_outliers: True
          #,numeric_features     = ['area', 'num_quartos', 'num_banheiros', 'garagem', 'num_andares', 'aceita_animais','mobilia', 'valor_condominio', 'valor_iptu', 'valor_seguro_incendio']
          #,categorical_features = ['cidade' ,'estado']

          #,ignore_features = ['cidade', 'estado']
          #,bin_numeric_features=['aceita_animais', 'mobilia']  #converte para variáveis binárias (0-1)

          ,numeric_imputation ="mean"       #Missing values for numeric features
          ,categorical_imputation = "mode"  #Missing values for categorical features

          #,normalize = True                 #Normalize the data
          #,normalize_method = 'minmax'      #Metodo para normalização

          #train_size = 0.8

          #,imputation_type='iterative'
          ,log_experiment = True
          ,experiment_name = 'exp_ML'
          ,session_id=123
         )
# Out:
# <style type="text/css">
# #T_5de34_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_5de34" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5de34_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_5de34_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5de34_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5de34_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_5de34_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_5de34_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5de34_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_5de34_row1_col1" class="data row1 col1" >price_in_pln</td>
#     </tr>
#     <tr>
#       <th id="T_5de34_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
#comparando os modelos
best = compare_models(fold = 5) #, sort='RMSE')
# Out:
# <style type="text/css">
# #T_13891 th {
#   text-align: left;
# }
# ...

# %%
#Listando os modelos
models()
# Out:
#                                        Name  \
# ID
# lr                        Linear Regression
# lasso                      Lasso Regression
# ridge                      Ridge Regression
# en                              Elastic Net
# lar                  Least Angle Regression
# llar           Lasso Least Angle Regression
# omp             Orthogonal Matching Pursuit
# br                           Bayesian Ridge
# ard       Automatic Relevance Determination
# par            Passive Aggressive Regressor
# ransac              Random Sample Consensus
# tr                       TheilSen Regressor
# huber                       Huber Regressor
# kr                             Kernel Ridge
# svm               Support Vector Regression
# knn                   K Neighbors Regressor
# dt                  Decision Tree Regressor
# rf                  Random Forest Regressor
# et                    Extra Trees Regressor
# ada                      AdaBoost Regressor
# ...

# %%
#Criando o modelo que obteve o melhor R2
xgboost = create_model('xgboost', fold = 5) #, cross_validation=True)
# Out:
# <style type="text/css">
# #T_a330f_row5_col0, #T_a330f_row5_col1, #T_a330f_row5_col2, #T_a330f_row5_col3, #T_a330f_row5_col4, #T_a330f_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_a330f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a330f_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_a330f_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_a330f_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_a330f_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_a330f_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_a330f_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...
